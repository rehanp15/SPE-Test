# %%
import requests
import base64

url = 'https://www.spesolution.com/trial/get-weather'

username = 'rehangidqu'
password = 'J9yXBrMw0dDLe7zK'

auth_string = f"{username}:{password}"

base64_auth_string = base64.b64encode(auth_string.encode()).decode('utf-8')

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer tUr78Ggg2iUyQUmpwKe1Lh1c1qgF9zxx',
    'x-api-key': base64_auth_string
}

body = {
    'resource_type': 'get_weather'
}

response = requests.post(url, headers=headers, json=body)

response.json()
# Out:
# {'status': '00',
#  'message': 'Yuhu! Congratulations, you passed the last trial!',
#  'temperature': '65',
#  'sky': 'clear sky',
#  'humidity': '52'}
